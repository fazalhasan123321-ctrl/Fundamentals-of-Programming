# %%
x=25
print(x)
# Out:
# 25

# %%
colors=["yellow","blue","black","pink","red"]
print(colors[2])
# Out:
# black

# %%
name=["rahul","keshav","amir"]
print(name)
# Out:
# ['rahul', 'keshav', 'amir']

# %%
name=["rahul","keshav","amir"]
name[0]="amit"
print(name)
# Out:
# ['amit', 'keshav', 'amir']

# %%
x=[64,56,35,36,56]
print(sum(x))
# Out:
# 247

# %%
fruits=["mango","banana"]
fruits.append("apple")
print(fruits)
# Out:
# ['mango', 'banana', 'apple']

# %%
fruits=["mango","banana"]
fruits.remove("banana")
print(fruits)
# Out:
# ['mango']

# %%
marks=[50,60,70,80]
marks[0]=55
print(marks)
# Out:
# [55, 60, 70, 80]

# %%
cities=["rajisthan","mumbai","punjab","haryana","gujarat"]
mean=len(cities)
print(mean)
# Out:
# 5
