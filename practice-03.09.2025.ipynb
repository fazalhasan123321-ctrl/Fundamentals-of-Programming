# %%
x=45
y=67
print(x+y)
# Out:
# 112

# %%
x=100
x-=35
print(x)
# Out:
# 65

# %%
x=23
y=12
print(x*y)
# Out:
# 276

# %%
x=144
y=12
print(x/y)
# Out:
# 12.0

# %%
x=29
y=5
print(x//y)
# Out:
# 5

# %%
x=75
y=8
print(x%y)
# Out:
# 3

# %%
x=5
y=4
print(x**y)
# Out:
# 625

# %%
x=25
y=7

# %%
print(x+y)
# Out:
# 32

# %%
print(x-y)
# Out:
# 18

# %%
print(x*y)
# Out:
# 175

# %%
print(x/y)
print(x//y)
print(x%y)
print(x**y)
# Out:
# 3.5714285714285716
# 3
# 4
# 6103515625

# %%
x=56
y=34
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 90
# 22
# 1904
# 1.6470588235294117

# %%
x=[67,78,34,76,38]
print(sum(x)/len(x))
# Out:
# 58.6
