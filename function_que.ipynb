# %%
def square(num):
    return num * num

n = int(input("Enter a number: "))
print("Square:", square(n))
# Out:
# Enter a number:  5
# Square: 25

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact

num = int(input("Enter a number: "))
print("Factorial:", factorial(num))
# Out:
# Enter a number:  5
# Factorial: 120

# %%
def check_even_odd(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

n = int(input("Enter a number: "))
print("The number is", check_even_odd(n))
# Out:
# Enter a number:  55
# The number is Odd

# %%
def calculate(a, b):
    total = a + b
    avg = total / 2
    return total, avg

x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
s, a = calculate(x, y)
print("Sum =", s, "Average =", a)
# Out:
# Enter first number:  6
# Enter second number:  8
# Sum = 14 Average = 7.0

# %%
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0
    for char in text:
        if char in vowels:
            count += 1
    return count

s = input("Enter a string: ")
print("Number of vowels:", count_vowels(s))
# Out:
# Enter a string:  keshav
# Number of vowels: 2

# %%
def simple_interest(p, r, t):
    return (p * r * t) / 100

# %%
print(simple_interest(1000, 5, 2))
# Out:
# 100.0

# %%
print(simple_interest(200, 6, 8))
# Out:
# 96.0

# %%
def get_even_numbers(lst):
    return [x for x in lst if x % 2 == 0]

# %%
print(get_even_numbers([1, 2, 3, 4, 5, 6]))
# Out:
# [2, 4, 6]

# %%
def count_words(text):
    return len(text.split())
print(count_words("Python is easy to learn"))
# Out:
# 5

# %%
def c_to_f(c):
    return (c * 9/5) + 32
print(c_to_f(25))
# Out:
# 77.0

# %%
def max_value_key(d):
    return max(d, key=d.get)
print(max_value_key({'a': 10, 'b': 20, 'c': 5}))
# Out:
# b

# %%
def word_count(paragraph, word):
    return paragraph.lower().split().count(word.lower())
print(word_count("Python is fun. I love Python.", "python"))
# Out:
# 1

# %%
def average_marks(marks):
    return sum(marks) / len(marks)
print(average_marks([90, 80, 70, 85]))
# Out:
# 81.25

# %%
def square_list(lst):
    return [x * x for x in lst]
print(square_list([1, 2, 3, 4]))
# Out:
# [1, 4, 9, 16]

# %%
def login(user, password):
    if user == "admin" and password == "1234":
        return "Login Successful"
    else:
        return "Invalid Credentials"
print(login("admin", "1234"))
# Out:
# Login Successful

# %%
def is_leap_year(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return "Leap Year"
    else:
        return "Not a Leap Year"
print(is_leap_year(2024))
# Out:
# Leap Year
